# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import re

# %%
imdb = urlopen('https://www.imdb.com/list/ls068010962/')
bsobj = soup(imdb.read())
print(bsobj.h1)
# Out:
# <h1 class="header list-name">Top 200 Best Indian Actors and Actresses</h1>

# %%
imdb = urlopen("https://www.imdb.com/list/ls053501318/")
bsobj = soup(imdb.read())

# %%
bsobj.findAll('h3')
# Out:
# [<h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1. </span>
#  <a href="/name/nm0000136"> Johnny Depp
#  </a> </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">2. </span>
#  <a href="/name/nm0000199"> Al Pacino
#  </a> </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">3. </span>
#  <a href="/name/nm0000134"> Robert De Niro
#  </a> </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">4. </span>
#  <a href="/name/nm0000228"> Kevin Spacey
#  </a> </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">5. </span>
#  <a href="/name/nm0000243"> Denzel Washington
#  </a> </h3>,
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">6. </span>
#  <a href="/name/nm0000128"> Russell Crowe
#  </a> </h3>,
#  <h3 class="lister-item-header">
# ...

# %%
bsobj.findAll(["h3","a"])
# Out:
# [<a href="/?ref_=nv_home"><svg class="ipc-logo WNY8DBPCS1ZbiSd7NoqdP" height="56" version="1.1" viewbox="0 0 64 32" width="98" xmlns="http://www.w3.org/2000/svg"><g fill="#F5C518"><rect height="100%" rx="4" width="100%" x="0" y="0"></rect></g><g fill="#000000" fill-rule="nonzero" transform="translate(8.000000, 7.000000)"><polygon points="0 18 5 18 5 0 0 0"></polygon><path d="M15.6725178,0 L14.5534833,8.40846934 L13.8582008,3.83502426 C13.65661,2.37009263 13.4632474,1.09175121 13.278113,0 L7,0 L7,18 L11.2416347,18 L11.2580911,6.11380679 L13.0436094,18 L16.0633571,18 L17.7583653,5.8517865 L17.7707076,18 L22,18 L22,0 L15.6725178,0 Z"></path><path d="M24,18 L24,0 L31.8045586,0 C33.5693522,0 35,1.41994415 35,3.17660424 L35,14.8233958 C35,16.5777858 33.5716617,18 31.8045586,18 L24,18 Z M29.8322479,3.2395236 C29.6339219,3.13233348 29.2545158,3.08072342 28.7026524,3.08072342 L28.7026524,14.8914865 C29.4312846,14.8914865 29.8796736,14.7604764 30.0478195,14.4865461 C30.2159654,14.2165858 30.30
# ...

# %%
for tag in bsobj.findAll(True):
    print(tag.name)
# Out:
# html
# head
# meta
# meta
# script
# script
# script
# title
# script
# script
# script
# link
# meta
# script
# script
# link
# link
# link
# link
# link
# link
# link
# link
# meta
# link
# script
# script
# script
# meta
# meta
# meta
# link
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# script
# script
# script
# script
# link
# link
# link
# link
# link
# link
# link
# noscript
# link
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# body
# script
# script
# script
# style
# div
# nav
# div
# div
# label
# svg
# path
# path
# label
# svg
# path
# path
# div
# input
# aside
# div
# div
# a
# svg
# g
# rect
# g
# polygon
# path
# path
# path
# label
# svg
# path
# path
# div
# div
# div
# input
# span
# label
# span
# svg
# path
# path
# span
# span
# svg
# path
# path
# div
# div
# ul
# a
# span
# a
# span
# a
# span
# a
# span
# a
# span
# a
# span
# a
# span
# a
# span
# a
# span
# a
# ...

# %%
bsobj.findAll('h1')
# Out:
# [<h1 class="header list-name">Top 50 Popular Hollywood Actors and Actresses</h1>]

# %%
bsobj.findAll('p')
# Out:
# [<p>Live :)</p>,
#  <p class="text-muted text-small">
#                          Actor <span class="ghost">|</span>
#  <a href="/title/tt0408236/"> Sweeney Todd: The Demon Barber of Fleet Street
#  </a> </p>,
#  <p>
#  Johnny Depp is perhaps one of the most versatile actors of his day and age in Hollywood.<br/><br/>He was born John Christopher Depp II in Owensboro, Kentucky, on June 9, 1963, to Betty Sue (Wells), who worked as a waitress, and John Christopher Depp, a civil engineer.<br/><br/>Depp was raised in Florida. He dropped ...                </p>,
#  <p class="text-muted text-small">
#                          Actor <span class="ghost">|</span>
#  <a href="/title/tt0070666/"> Serpico
#  </a> </p>,
#  <p>
# ...

# %%
bsobj.findAll(href=re.compile('/name/'))
# Out:
# [<a aria-disabled="false" class="ipc-list__item nav-link nav-link--hideXS nav-link--hideS nav-link--hideM NavLink-sc-19k0khm-0 LrpYY ipc-list__item--indent-one" href="https://www.imdb.com/search/name/?match_all=true&amp;ref_=nv_cel_m" role="menuitem" tabindex="-1"><span class="ipc-list-item__text" role="presentation">Most Popular Celebs</span></a>,
#  <a href="/name/nm0000136/"> <img alt="Johnny Depp" height="209" src="https://m.media-amazon.com/images/M/MV5BMTM0ODU5Nzk2OV5BMl5BanBnXkFtZTcwMzI2ODgyNQ@@._V1_UY209_CR3,0,140,209_AL_.jpg" width="140"/>
#  </a>,
#  <a href="/name/nm0000136"> Johnny Depp
#  </a>,
#  <a href="/name/nm0000199/"> <img alt="Al Pacino" height="209" src="https://m.media-amazon.com/images/M/MV5BMTQzMzg1ODAyNl5BMl5BanBnXkFtZTYwMjAxODQ1._V1_UX140_CR0,0,140,209_AL_.jpg" width="140"/>
#  </a>,
#  <a href="/name/nm0000199"> Al Pacino
#  </a>,
# ...

# %%
bsobj.findAll(id = 'list-overview-created')
# Out:
# [<span class="text-muted" id="list-overview-created">created - 24 May 2013</span>]

# %%
bsobj.findAll(class = 'text-muted')
# Out:
#   File "C:\Users\felix\AppData\Local\Temp/ipykernel_20392/1646409867.py", line 1
#     bsobj.findAll(class = 'text-muted')
#                   ^
# SyntaxError: invalid syntax

# %%
bsobj.findAll(attrs={'class':'text-muted'})
# Out:
# [<span class="text-muted" id="list-overview-created">created - 24 May 2013</span>,
#  <span class="text-muted" id="list-overview-lastupdated">updated - 24 May 2013</span>,
#  <span class="privacy-overview text-muted">
#          Public
#      </span>,
#  <p class="text-muted text-small">
#                          Actor <span class="ghost">|</span>
#  <a href="/title/tt0408236/"> Sweeney Todd: The Demon Barber of Fleet Street
#  </a> </p>,
#  <p class="text-muted text-small">
#                          Actor <span class="ghost">|</span>
#  <a href="/title/tt0070666/"> Serpico
#  </a> </p>,
#  <p class="text-muted text-small">
#                          Actor <span class="ghost">|</span>
#  <a href="/title/tt0101540/"> Cape Fear
#  </a> </p>,
#  <p class="text-muted text-small">
#                          Actor <span class="ghost">|</span>
#  <a href="/title/tt0114814/"> The Usual Suspects
#  </a> </p>,
#  <p class="text-muted text-small">
# ...

# %%
bsobj.findAll('p',limit=3)
# Out:
# [<p>Live :)</p>,
#  <p class="text-muted text-small">
#                          Actor <span class="ghost">|</span>
#  <a href="/title/tt0408236/"> Sweeney Todd: The Demon Barber of Fleet Street
#  </a> </p>,
#  <p>
#  Johnny Depp is perhaps one of the most versatile actors of his day and age in Hollywood.<br/><br/>He was born John Christopher Depp II in Owensboro, Kentucky, on June 9, 1963, to Betty Sue (Wells), who worked as a waitress, and John Christopher Depp, a civil engineer.<br/><br/>Depp was raised in Florida. He dropped ...                </p>]

# %%
bsobj.findAll(text = 'Johnny')
# Out:
# []

# %%
bsobj.findAll(text='Leonardo')
# Out:
# []
